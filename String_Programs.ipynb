# %%
"""
1. Username Validation System
Scenario

A website allows usernames containing only letters and digits.

Task

Check whether a username is valid.

Input
user = "Rathna123"
Output
Valid Username
Hint

Use:

isalnum()
"""

# %%
username = input()
if username.isalnum():
    print("Valid Username")
else:
    print("Invalid Username")
# Out:
# Rathna123
# Valid Username

# %%
"""
2. Password Strength Checker
Scenario

A company requires passwords to:

Have at least 8 characters
Contain one uppercase letter
Contain one digit
Task

Check if the password is strong.

Input
password = "Python123"
Output
Strong Password
"""

# %%
password = input()
if password.isalnum() and len(password) >= 8 and any(c.isupper() for c in password):
  print("Strong Password")
else:
  print("Not a Strong Password")
# Out:
# Python123
# Strong Password

# %%
"""
3. Email Domain Extractor
Scenario

An HR system stores employee emails.

Task

Extract the domain name.

Input
email = "rathna@gmail.com"
Output
gmail.com
Hint

Use:

split("@")
"""

# %%
email = input().split('@')
print(email[1])
# Out:
# rathna@gmail.com
# gmail.com

# %%
"""
4. Log File Analyzer
Scenario

A server stores logs.

Task

Count how many times "ERROR" appears.

Input
log = "ERROR INFO ERROR WARNING ERROR"
Output
3
Hint

Use:

count()
"""

# %%
log_text = input().split()
print(log_text.count("ERROR"))
# Out:
# ERROR INFO ERROR WARNING ERROR
# 3

# %%
"""
5. Chat Message Cleaner
Scenario

A chat application removes extra spaces.

Input
msg = "   Hello    World   "
Output
Hello World
Hint
split()
join()
"""

# %%
msg = input()
msg = msg.split()
msg = " ".join(msg)
print(msg)
# Out:
#    Hello    World
# Hello World

# %%
"""
6. Product Code Verification
Scenario

A warehouse stores product codes.

Task

Check whether the code starts with "PRD".

Input
code = "PRD5678"
Output
Valid Product
Hint
startswith()
"""

# %%
code = input()
if code.startswith("PRD"):
  print("Valid Product")
else:
  print("Invalid Product")
# Out:
# PRD5678
# Valid Product

# %%
"""
7. Reverse Customer Feedback
Scenario

A company wants to display feedback in reverse order.

Input
feedback = "Excellent"
Output
tnellecxE
Hint
[::-1]
"""

# %%
feedback = input()
print(feedback[::-1])
# Out:
# Excellent
# tnellecxE

# %%
"""
8. Word Frequency Counter
Scenario

Analyze customer reviews.

Input
review = "good service good quality good support"
Task

Count frequency of each word.

Output
good : 3
service : 1
quality : 1
support : 1
"""

# %%
review = input().split()
temp = []
for i in range(len(review)):
  if review[i] not in temp:
    temp.append(review[i])
    print(f"{review[i]} : {review.count(review[i])}")
# Out:
# good service good quality good support
# good : 3
# service : 1
# quality : 1
# support : 1

# %%
"""
9. Secret Message Encryption
Scenario

Shift each character by one position.

Input
abc
Output
bcd
Example
a -> b
b -> c
c -> d
"""

# %%
message = input()
for i in message:
  print(chr(ord(i)+1),end="")
# Out:
# abc
# bcd

# %%
"""
10. Anagram Checker (Most Asked)
Scenario

Two encrypted messages are considered identical if they contain the same characters in different orders.

Input
s1 = "listen"
s2 = "silent"
Output
Anagram
"""

# %%
s1 = input().lower()
s2 = input().lower()
if sorted(s1) == sorted(s2):
  print("Anagram")
else:
  print("Not Anagram")
# Out:
# LiStEn
# SILent
# Anagram

# %%
# 1. Reverse a string without slicing
s1 = input().strip()
s2 = ""
for i in range(len(s1)-1,-1,-1):
    s2 = s2 + (s1[i])
print(s2)
# Out:
# Rajaram
# marajaR

# %%
#2 Check palindrome without using reverse
s1 = input().strip()
s2 = ""
for i in range(len(s1)-1,-1,-1):
    s2 = s2 + s1[i]
if s1 == s2:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# malayalam
# Palindrome

# %%
# Two pointer technique
s = input()
left, right = 0, len(s) -1
while left < right:
  if s[left] != s[right]:
    print("Not a palindrome")
  left += 1
  right -= 1
print("Palindrome")
# Out:
# malayalam
# Palindrome

# %%
#3 Count number of consonants and vowels in the given string
vowel_count, consonant_count = 0, 0
string = input().lower()
for i in string:
    if i in ["a","e","i","o","u"]:
        vowel_count += 1
    else:
        consonant_count += 1
print("No of vowels:",vowel_count)
print("No of consonants:",consonant_count)
# Out:
# Count number of consonants and vowels in the given string
# No of vowels: 16
# No of consonants: 41

# %%
#4 Find Duplicate characters
s = input()
s1 = ""
dup = ""
for i in s:
    if i not in s1:
        s1 = s1 + i
    else:
        dup = dup +" "+ i
print("Duplicate Characters:",dup)
# Out:
# Characters can  be alphabets or numbers
# Duplicate Characters:  a r c a     e   a h a b e t s   r   n b e r s

# %%
#5 Remove Special Characters
s = input()
s1 = ""
for i in s:
    if i.isalnum() or i.isspace():
        s1 = s1 + i
print(s1)
# Out:
# H!@#ell)(&o Wor:'[]<>-+ld
# Hello World
